# %% [markdown]
# Problem statement.
#
# Build a recommender system by using cosine simillarties score.

# %%
import pandas as pd
import numpy as np

# %%
book=pd.read_csv('book.csv',encoding='latin-1')
book
# Out:
#       Unnamed: 0  User.ID                                         Book.Title  \
# 0              1   276726                                Classical Mythology
# 1              2   276729                                       Clara Callan
# 2              3   276729                               Decision in Normandy
# 3              4   276736  Flu: The Story of the Great Influenza Pandemic...
# 4              5   276737                             The Mummies of Urumchi
# ...          ...      ...                                                ...
# 9995        9996   162121       American Fried: Adventures of a Happy Eater.
# 9996        9997   162121                              Cannibal In Manhattan
# 9997        9998   162121                    How to Flirt: A Practical Guide
# 9998        9999   162121                                           Twilight
# 9999       10000   162129                       Kids Say the Darndest Things
#
#       Book.Rating
# 0               5
# ...

# %%
book_1=book.drop('Unnamed: 0',axis=1)
book_1
# Out:
#       User.ID                                         Book.Title  Book.Rating
# 2401        8                                              Wings            5
# 2400        8  The Western way: A practical guide to the West...            5
# 2399        8                            Ancient Celtic Romances            5
# 2402        8                                           Truckers            5
# 2405        8                                  The Art Of Celtia            7
# ...       ...                                                ...          ...
# 2395   278854      La crÃ³nica del PerÃº (CrÃ³nicas de AmÃ©rica)            7
# 2398   278854  Celtic Mythology (Library of the World's Myths...            8
# 2393   278854                         A corrente de Trewis Scott            7
# 2394   278854                                      As valkÃ­rias            7
# 2397   278854     A Treasury of Irish Myth, Legend, and Folklore            6
#
# [10000 rows x 3 columns]

# %%
len(book_1['Book.Title'].unique())
# Out:
# 9659

# %%
books_df =book_1.pivot_table(index='User.ID',
                                 columns='Book.Title',
                                 values='Book.Rating').reset_index()
books_df
# Out:
# Book.Title  User.ID   Jason, Madison &amp  \
# 0                 8                   NaN
# 1                 9                   NaN
# 2                10                   NaN
# 3                12                   NaN
# 4                14                   NaN
# ...             ...                   ...
# 2177         278846                   NaN
# 2178         278849                   NaN
# 2179         278851                   NaN
# 2180         278852                   NaN
# 2181         278854                   NaN
#
# Book.Title   Other Stories;Merril;1985;McClelland &amp  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 2177                                               NaN
# ...

# %%
books_df.index = book_1['User.ID'].unique()

# %%
books_df
# Out:
# Book.Title  User.ID   Jason, Madison &amp  \
# 8                 8                   NaN
# 9                 9                   NaN
# 10               10                   NaN
# 12               12                   NaN
# 14               14                   NaN
# ...             ...                   ...
# 278846       278846                   NaN
# 278849       278849                   NaN
# 278851       278851                   NaN
# 278852       278852                   NaN
# 278854       278854                   NaN
#
# Book.Title   Other Stories;Merril;1985;McClelland &amp  \
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 12                                                 NaN
# 14                                                 NaN
# ...                                                ...
# 278846                                             NaN
# ...

# %%
books_df.fillna(0, inplace=True)

# %%
books_df
# Out:
# Book.Title  User.ID   Jason, Madison &amp  \
# 8                 8                   0.0
# 9                 9                   0.0
# 10               10                   0.0
# 12               12                   0.0
# 14               14                   0.0
# ...             ...                   ...
# 278846       278846                   0.0
# 278849       278849                   0.0
# 278851       278851                   0.0
# 278852       278852                   0.0
# 278854       278854                   0.0
#
# Book.Title   Other Stories;Merril;1985;McClelland &amp  \
# 8                                                  0.0
# 9                                                  0.0
# 10                                                 0.0
# 12                                                 0.0
# 14                                                 0.0
# ...                                                ...
# 278846                                             0.0
# ...

# %%
#Calculating Cosine Similarity between Users
from sklearn.metrics import pairwise_distances
#from scipy.spatial.distance import cosine, correlation

# %%
user_sim = 1 - pairwise_distances( books_df.values,metric='cosine')

# %%
user_sim
# Out:
# array([[1.        , 0.39429125, 0.40634798, ..., 0.4738791 , 0.4738791 ,
#         0.4738791 ],
#        [0.39429125, 1.        , 0.71347724, ..., 0.83205029, 0.83205029,
#         0.83205029],
#        [0.40634798, 0.71347724, 1.        , ..., 0.85749292, 0.85749293,
#         0.85749292],
#        ...,
#        [0.4738791 , 0.83205029, 0.85749292, ..., 1.        , 1.        ,
#         0.99999999],
#        [0.4738791 , 0.83205029, 0.85749293, ..., 1.        , 1.        ,
#         1.        ],
#        [0.4738791 , 0.83205029, 0.85749292, ..., 0.99999999, 1.        ,
#         1.        ]])

# %%
user_sim_df = pd.DataFrame(user_sim)

# %%
user_sim_df.index = books_df['User.ID'].unique()
user_sim_df.columns = books_df['User.ID'].unique()

# %%
np.fill_diagonal(user_sim, 0)
user_sim_df.iloc[0:5, 0:5]
# Out:
#           8         9         10        12        14
# 8   0.000000  0.394291  0.406348  0.364044  0.395067
# 9   0.394291  0.000000  0.713477  0.639199  0.693670
# 10  0.406348  0.713477  0.000000  0.658744  0.714881
# 12  0.364044  0.639199  0.658744  0.000000  0.640457
# 14  0.395067  0.693670  0.714881  0.640457  0.000000

# %%
user_sim_df.idxmax(axis=1)[8:14]
# Out:
# 22    278755
# 26    278755
# 32    278755
# 39    278755
# 42    278755
# 44    278755
# dtype: int64

# %%
book[(book['User.ID']==8) | (book['User.ID']==278755)]
# Out:
#       Unnamed: 0  User.ID                                         Book.Title  \
# 2401        2402        8                                              Wings
# 2400        2401        8  The Western way: A practical guide to the West...
# 2399        2400        8                            Ancient Celtic Romances
# 2402        2403        8                                           Truckers
# 2405        2406        8                                  The Art Of Celtia
# 2403        2404        8                Keepers of the Earth Teachers Guide
# 2404        2405        8                            The Celts Activity Book
# 2320        2321   278755              The Elements of Style, Fourth Edition
#
#       Book.Rating
# 2401            5
# 2400            5
# 2399            5
# 2402            5
# 2405            7
# 2403            6
# 2404            6
# 2320            1

# %%
reader1=book[(book['User.ID']==8)]
reader1
# Out:
#       Unnamed: 0  User.ID                                         Book.Title  \
# 2401        2402        8                                              Wings
# 2400        2401        8  The Western way: A practical guide to the West...
# 2399        2400        8                            Ancient Celtic Romances
# 2402        2403        8                                           Truckers
# 2405        2406        8                                  The Art Of Celtia
# 2403        2404        8                Keepers of the Earth Teachers Guide
# 2404        2405        8                            The Celts Activity Book
#
#       Book.Rating
# 2401            5
# 2400            5
# 2399            5
# 2402            5
# 2405            7
# 2403            6
# 2404            6

# %%
reader2=book[(book['User.ID']==278755)]
reader2
# Out:
#       Unnamed: 0  User.ID                             Book.Title  Book.Rating
# 2320        2321   278755  The Elements of Style, Fourth Edition            1

# %%
pd.merge(reader1,reader2,on='Book.Title',how='outer')
# Out:
#    Unnamed: 0_x  User.ID_x                                         Book.Title  \
# 0        2402.0        8.0                                              Wings
# 1        2401.0        8.0  The Western way: A practical guide to the West...
# 2        2400.0        8.0                            Ancient Celtic Romances
# 3        2403.0        8.0                                           Truckers
# 4        2406.0        8.0                                  The Art Of Celtia
# 5        2404.0        8.0                Keepers of the Earth Teachers Guide
# 6        2405.0        8.0                            The Celts Activity Book
# 7           NaN        NaN              The Elements of Style, Fourth Edition
#
#    Book.Rating_x  Unnamed: 0_y  User.ID_y  Book.Rating_y
# 0            5.0           NaN        NaN            NaN
# 1            5.0           NaN        NaN            NaN
# 2            5.0           NaN        NaN            NaN
# ...
